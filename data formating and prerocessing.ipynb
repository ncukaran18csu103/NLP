# %%
import numpy as np
from sklearn.utils import shuffle
import re
import time
import collections
import os

# %%
import pandas as pd

# %%
data=pd.read_csv('conversation1.csv')
data
# Out:
#                    Human Support: How can I help you?
# 0   User: I am getting error whiling releasing a p...
# 1           Human Support:what error are you getting?
# 2    User: It says somthing about conditions not met.
# 3   Human Support: Can you give me part number you...
# 4                               User: It is X00000255
# 5   Human Support: I have done a quick check and f...
# 6                          User: ok. How do I do that
# 7   Human Support: Refer this instruction document...
# 8                                           User: ok.
# 9   User: which category should I use for steel pipe.
# 10                   Human Support: use raw materials
# 11                          User: still getting error
# 12          Human Support: what does it say this time
# 13  User: something about you do not have access t...
# 14                           Human Support:which part
# 15                                     User:same part
# 16                           Human Support:X00000211?
# 17                                           User:yes
# 18                    Human Support:ok. let me check.
# 19  Human Support: This part is not released and b...
# 20      User: why can`t I release it with my assembly
# 21  Human Support: Sorry, it is not allowed to rel...
# 22                          User:ok, who is the owner
# 23              Human Support:Kjetil Kleppe is owner.
# 24  User:ok I send him mail, but this is really fr...
# 25  Human Support: I can understand. can i help wi...
# 26     User: Yes, can you ask him to relase the part.
# 27                   Human Support: ok. will do that.
# 28                                       User:Thanks.
# 29   Human Support:Anything else cal i help you with.
# 30  User:yes. How to delete this circular icon i g...
# 31    Human Support: that is a work in progress icon.
# 32      User:why do i get it even though i got error.
# 33             Human Support: yes it should not come.
# 34  User: you can select item revision and do wher...
# 35  Human Support: i dont know what you are talkin...
# 36           User: ok i will do it. give me a moment.
# 37                                        User: Done.
# 38                              Human Support: thanks
# 39            User:Anything else can i help you with.
# 40  Human Support:yes, i am new to company, where ...
# 41  Human Support: you can get all TC help on intr...
# 42            User:ok. i cant open it. access denied.
# 43  Human Support: please send ticket to IT helpde...
# 44                      User:ok. what is meant by SLU
# 45  Human Support: SLU is a 120% BOM for a particu...
# 46                                User:ok thanks, bye
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
word='User'
list=[]
with open('conversation1.csv', 'r') as file:
        for line in file:
            if word in line:
                list.append(line)

list1=pd.DataFrame(list)
list1
list1.to_csv('User.csv')

# %%
word="User:"
list3=[]
for line in list:
    if word in line:
        repStr = re.sub(word," ",line)
        list3.append(repStr)

# %%
list3=pd.DataFrame(list3)
list3
list3.to_csv('User1.csv')

# %%
user1=pd.read_csv('User1.csv')
user1
# Out:
#     Unnamed: 0                                                  0
# 0            0  "  I am getting error whiling releasing a part...
# 1            1   "  It says somthing about conditions not met."\n
# 2            2                              "  It is X00000255"\n
# 3            3                         "  ok. How do I do that"\n
# 4            4                                          "  ok."\n
# 5            5  "  which category should I use for steel pipe."\n
# 6            6                          "  still getting error"\n
# 7            7  "  something about you do not have access to r...
# 8            8                                     " same part"\n
# 9            9                                           " yes"\n
# 10          10      "  why can`t I release it with my assembly"\n
# 11          11                          " ok, who is the owner"\n
# 12          12  " ok I send him mail, but this is really frust...
# 13          13     "  Yes, can you ask him to relase the part."\n
# 14          14                                       " Thanks."\n
# 15          15  " yes. How to delete this circular icon i got ...
# 16          16      " why do i get it even though i got error."\n
# 17          17  "  you can select item revision and do where r...
# 18          18           "  ok i will do it. give me a moment."\n
# 19          19                                        "  Done."\n
# 20          20            " Anything else can i help you with."\n
# 21          21            " ok. i cant open it. access denied."\n
# 22          22                      " ok. what is meant by SLU"\n
# 23          23                                " ok thanks, bye"\n

# %%
word='Human Support'
list=[]
with open('conversation1.csv', 'r') as file:
  for line in file:
    if word in line:
      repStr = re.sub(word," ",line)
      list.append(line)

list1=pd.DataFrame(list)
list1
list1.to_csv('Human.csv')

# %%
human=pd.read_csv('Human.csv')
human
# Out:
#     Unnamed: 0                                                  0
# 0            0             "Human Support: How can I help you?"\n
# 1            1      "Human Support:what error are you getting?"\n
# 2            2  "Human Support: Can you give me part number yo...
# 3            3  "Human Support: I have done a quick check and ...
# 4            4  "Human Support: Refer this instruction documen...
# 5            5               "Human Support: use raw materials"\n
# 6            6      "Human Support: what does it say this time"\n
# 7            7                       "Human Support:which part"\n
# 8            8                       "Human Support:X00000211?"\n
# 9            9                "Human Support:ok. let me check."\n
# 10          10  "Human Support: This part is not released and ...
# 11          11  "Human Support: Sorry, it is not allowed to re...
# 12          12          "Human Support:Kjetil Kleppe is owner."\n
# 13          13  "Human Support: I can understand. can i help w...
# 14          14               "Human Support: ok. will do that."\n
# 15          15  "Human Support:Anything else cal i help you wi...
# 16          16  "Human Support: that is a work in progress ico...
# 17          17         "Human Support: yes it should not come."\n
# 18          18  "Human Support: i dont know what you are talki...
# 19          19                          "Human Support: thanks"\n
# 20          20  "Human Support:yes, i am new to company, where...
# 21          21  "Human Support: you can get all TC help on int...
# 22          22  "Human Support: please send ticket to IT helpd...
# 23          23  "Human Support: SLU is a 120% BOM for a partic...

# %%
word="Human Support:"
list2=[]
for line in list:
  if word in line:
    repStr = re.sub(word," ",line)
    list2.append(repStr)

# %%
list3=pd.DataFrame(list2)
list3
list3.to_csv('Human1.csv')

# %%
Human1=pd.read_csv('Human1.csv')

# %%
user1=pd.read_csv('User1.csv')
user1
# Out:
#     Unnamed: 0                                          Questions
# 0            0  "  I am getting error whiling releasing a part...
# 1            1  "  It says somthing about conditions not met."...
# 2            2                            "  It is X00000255"\r\n
# 3            3                       "  ok. How do I do that"\r\n
# 4            4                                        "  ok."\r\n
# 5            5  "  which category should I use for steel pipe....
# 6            6                        "  still getting error"\r\n
# 7            7  "  something about you do not have access to r...
# 8            8                                   " same part"\r\n
# 9            9                                         " yes"\r\n
# 10          10    "  why can`t I release it with my assembly"\r\n
# 11          11                        " ok, who is the owner"\r\n
# 12          12  " ok I send him mail, but this is really frust...
# 13          13   "  Yes, can you ask him to relase the part."\r\n
# 14          14                                     " Thanks."\r\n
# 15          15  " yes. How to delete this circular icon i got ...
# 16          16    " why do i get it even though i got error."\r\n
# 17          17  "  you can select item revision and do where r...
# 18          18         "  ok i will do it. give me a moment."\r\n
# 19          19                                      "  Done."\r\n
# 20          20          " Anything else can i help you with."\r\n
# 21          21          " ok. i cant open it. access denied."\r\n
# 22          22                    " ok. what is meant by SLU"\r\n
# 23          23                              " ok thanks, bye"\r\n

# %%
def decontractions(phrase):
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"won\’t", "will not", phrase)
    phrase = re.sub(r"can\’t", "can not", phrase)

    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)

    phrase = re.sub(r"n\’t", " not", phrase)
    phrase = re.sub(r"\’re", " are", phrase)
    phrase = re.sub(r"\’s", " is", phrase)
    phrase = re.sub(r"\’d", " would", phrase)
    phrase = re.sub(r"\’ll", " will", phrase)
    phrase = re.sub(r"\’t", " not", phrase)
    phrase = re.sub(r"\’ve", " have", phrase)
    phrase = re.sub(r"\’m", " am", phrase)

    return phrase

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', string)

# %%
EMOTICONS = {
    u":‑\)":"Happy face or smiley",
    u":\)":"Happy face or smiley",
    u":-\]":"Happy face or smiley",
    u":\]":"Happy face or smiley",
    u":-3":"Happy face smiley",
    u":3":"Happy face smiley",
    u":->":"Happy face smiley",
    u":>":"Happy face smiley",
    u"8-\)":"Happy face smiley",
    u":o\)":"Happy face smiley",
    u":-\}":"Happy face smiley",
    u":\}":"Happy face smiley",
    u":-\)":"Happy face smiley",
    u":c\)":"Happy face smiley",
    u":\^\)":"Happy face smiley",
    u"=\]":"Happy face smiley",
    u"=\)":"Happy face smiley",
    u":‑D":"Laughing, big grin or laugh with glasses",
    u":D":"Laughing, big grin or laugh with glasses",
    u"8‑D":"Laughing, big grin or laugh with glasses",
    u"8D":"Laughing, big grin or laugh with glasses",
    u"X‑D":"Laughing, big grin or laugh with glasses",
    u"XD":"Laughing, big grin or laugh with glasses",
    u"=D":"Laughing, big grin or laugh with glasses",
    u"=3":"Laughing, big grin or laugh with glasses",
    u"B\^D":"Laughing, big grin or laugh with glasses",
    u":-\)\)":"Very happy",
    u":‑\(":"Frown, sad, andry or pouting",
    u":-\(":"Frown, sad, andry or pouting",
    u":\(":"Frown, sad, andry or pouting",
    u":‑c":"Frown, sad, andry or pouting",
    u":c":"Frown, sad, andry or pouting",
    u":‑<":"Frown, sad, andry or pouting",
    u":<":"Frown, sad, andry or pouting",
    u":‑\[":"Frown, sad, andry or pouting",
    u":\[":"Frown, sad, andry or pouting",
    u":-\|\|":"Frown, sad, andry or pouting",
    u">:\[":"Frown, sad, andry or pouting",
    u":\{":"Frown, sad, andry or pouting",
    u":@":"Frown, sad, andry or pouting",
    u">:\(":"Frown, sad, andry or pouting",
    u":'‑\(":"Crying",
    u":'\(":"Crying",
    u":'‑\)":"Tears of happiness",
    u":'\)":"Tears of happiness",
    u"D‑':":"Horror",
    u"D:<":"Disgust",
    u"D:":"Sadness",
    u"D8":"Great dismay",
    u"D;":"Great dismay",
    u"D=":"Great dismay",
    u"DX":"Great dismay",
    u":‑O":"Surprise",
    u":O":"Surprise",
    u":‑o":"Surprise",
    u":o":"Surprise",
    u":-0":"Shock",
    u"8‑0":"Yawn",
    u">:O":"Yawn",
    u":-\*":"Kiss",
    u":\*":"Kiss",
    u":X":"Kiss",
    u";‑\)":"Wink or smirk",
    u";\)":"Wink or smirk",
    u"\*-\)":"Wink or smirk",
    u"\*\)":"Wink or smirk",
    u";‑\]":"Wink or smirk",
    u";\]":"Wink or smirk",
    u";\^\)":"Wink or smirk",
    u":‑,":"Wink or smirk",
    u";D":"Wink or smirk",
    u":‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"X‑P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"XP":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":Þ":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"d:":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"=p":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u">:P":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u":‑/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":-[.]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u">:/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=/":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=[(\\\)]":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u"=L":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":S":"Skeptical, annoyed, undecided, uneasy or hesitant",
    u":‑\|":"Straight face",
    u":\|":"Straight face",
    u":$":"Embarrassed or blushing",
    u":‑x":"Sealed lips or wearing braces or tongue-tied",
    u":x":"Sealed lips or wearing braces or tongue-tied",
    u":‑#":"Sealed lips or wearing braces or tongue-tied",
    u":#":"Sealed lips or wearing braces or tongue-tied",
    u":‑&":"Sealed lips or wearing braces or tongue-tied",
    u":&":"Sealed lips or wearing braces or tongue-tied",
    u"O:‑\)":"Angel, saint or innocent",
    u"O:\)":"Angel, saint or innocent",
    u"0:‑3":"Angel, saint or innocent",
    u"0:3":"Angel, saint or innocent",
    u"0:‑\)":"Angel, saint or innocent",
    u"0:\)":"Angel, saint or innocent",
    u":‑b":"Tongue sticking out, cheeky, playful or blowing a raspberry",
    u"0;\^\)":"Angel, saint or innocent",
    u">:‑\)":"Evil or devilish",
    u">:\)":"Evil or devilish",
    u"\}:‑\)":"Evil or devilish",
    u"\}:\)":"Evil or devilish",
    u"3:‑\)":"Evil or devilish",
    u"3:\)":"Evil or devilish",
    u">;\)":"Evil or devilish",
    u"\|;‑\)":"Cool",
    u"\|‑O":"Bored",
    u":‑J":"Tongue-in-cheek",
    u"#‑\)":"Party all night",
    u"%‑\)":"Drunk or confused",
    u"%\)":"Drunk or confused",
    u":-###..":"Being sick",
    u":###..":"Being sick",
    u"<:‑\|":"Dump",
    u"\(>_<\)":"Troubled",
    u"\(>_<\)>":"Troubled",
    u"\(';'\)":"Baby",
    u"\(\^\^>``":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(\^_\^;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(~_~;\) \(・\.・;\)":"Nervous or Embarrassed or Troubled or Shy or Sweat drop",
    u"\(-_-\)zzz":"Sleeping",
    u"\(\^_-\)":"Wink",
    u"\(\(\+_\+\)\)":"Confused",
    u"\(\+o\+\)":"Confused",
    u"\(o\|o\)":"Ultraman",
    u"\^_\^":"Joyful",
    u"\(\^_\^\)/":"Joyful",
    u"\(\^O\^\)／":"Joyful",
    u"\(\^o\^\)／":"Joyful",
    u"\(__\)":"Kowtow as a sign of respect, or dogeza for apology",
    u"_\(\._\.\)_":"Kowtow as a sign of respect, or dogeza for apology",
    u"<\(_ _\)>":"Kowtow as a sign of respect, or dogeza for apology",
    u"<m\(__\)m>":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(__\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"m\(_ _\)m":"Kowtow as a sign of respect, or dogeza for apology",
    u"\('_'\)":"Sad or Crying",
    u"\(/_;\)":"Sad or Crying",
    u"\(T_T\) \(;_;\)":"Sad or Crying",
    u"\(;_;":"Sad of Crying",
    u"\(;_:\)":"Sad or Crying",
    u"\(;O;\)":"Sad or Crying",
    u"\(:_;\)":"Sad or Crying",
    u"\(ToT\)":"Sad or Crying",
    u";_;":"Sad or Crying",
    u";-;":"Sad or Crying",
    u";n;":"Sad or Crying",
    u";;":"Sad or Crying",
    u"Q\.Q":"Sad or Crying",
    u"T\.T":"Sad or Crying",
    u"QQ":"Sad or Crying",
    u"Q_Q":"Sad or Crying",
    u"\(-\.-\)":"Shame",
    u"\(-_-\)":"Shame",
    u"\(一一\)":"Shame",
    u"\(；一_一\)":"Shame",
    u"\(=_=\)":"Tired",
    u"\(=\^\·\^=\)":"cat",
    u"\(=\^\·\·\^=\)":"cat",
    u"=_\^=	":"cat",
    u"\(\.\.\)":"Looking down",
    u"\(\._\.\)":"Looking down",
    u"\^m\^":"Giggling with hand covering mouth",
    u"\(\・\・?":"Confusion",
    u"\(?_?\)":"Confusion",
    u">\^_\^<":"Normal Laugh",
    u"<\^!\^>":"Normal Laugh",
    u"\^/\^":"Normal Laugh",
    u"\（\*\^_\^\*）" :"Normal Laugh",
    u"\(\^<\^\) \(\^\.\^\)":"Normal Laugh",
    u"\(^\^\)":"Normal Laugh",
    u"\(\^\.\^\)":"Normal Laugh",
    u"\(\^_\^\.\)":"Normal Laugh",
    u"\(\^_\^\)":"Normal Laugh",
    u"\(\^\^\)":"Normal Laugh",
    u"\(\^J\^\)":"Normal Laugh",
    u"\(\*\^\.\^\*\)":"Normal Laugh",
    u"\(\^—\^\）":"Normal Laugh",
    u"\(#\^\.\^#\)":"Normal Laugh",
    u"\（\^—\^\）":"Waving",
    u"\(;_;\)/~~~":"Waving",
    u"\(\^\.\^\)/~~~":"Waving",
    u"\(-_-\)/~~~ \($\·\·\)/~~~":"Waving",
    u"\(T_T\)/~~~":"Waving",
    u"\(ToT\)/~~~":"Waving",
    u"\(\*\^0\^\*\)":"Excited",
    u"\(\*_\*\)":"Amazed",
    u"\(\*_\*;":"Amazed",
    u"\(\+_\+\) \(@_@\)":"Amazed",
    u"\(\*\^\^\)v":"Laughing,Cheerful",
    u"\(\^_\^\)v":"Laughing,Cheerful",
    u"\(\(d[-_-]b\)\)":"Headphones,Listening to music",
    u'\(-"-\)':"Worried",
    u"\(ーー;\)":"Worried",
    u"\(\^0_0\^\)":"Eyeglasses",
    u"\(\＾ｖ\＾\)":"Happy",
    u"\(\＾ｕ\＾\)":"Happy",
    u"\(\^\)o\(\^\)":"Happy",
    u"\(\^O\^\)":"Happy",
    u"\(\^o\^\)":"Happy",
    u"\)\^o\^\(":"Happy",
    u":O o_O":"Surprised",
    u"o_0":"Surprised",
    u"o\.O":"Surpised",
    u"\(o\.o\)":"Surprised",
    u"oO":"Surprised",
    u"\(\*￣m￣\)":"Dissatisfied",
    u"\(‘A`\)":"Snubbed or Deflated"
}

# %%
def remove_emoticons(text):
    " Remove emoticons from text"
    emoticon_pattern = re.compile(u'(' + u'|'.join(k for k in EMOTICONS) + u')')
    return emoticon_pattern.sub(r'', text)

# %%
def clean_text(text):
    """
    This function clean the given data and preprocess it.
    """
    # Lower casting
    text = text.lower()

    # Remove all the mentions (words starting with '@')
    text = re.sub(r"@\S+", '', text)

    # Remove URL
    #text = re.sub(r"http\S+", "", text)

    # Remove html tags
    #text = BeautifulSoup(text, 'lxml').get_text()

    # Decontracted
    text = decontractions(text)

    # Remove emoji
    text = remove_emoji(text)

    # Remove emoticons
    text = remove_emoticons(text)

    # Remove words with digit
    #text = re.sub("\S*\d\S*", "", text).strip()

    # Remove any special charecters and punctuations
    #text = re.sub("[^A-Za-z\n]", " ", text)

    # Remove more than 1 space
    text = " ".join(text.split())

    return text

# %%
from tqdm import tqdm
tqdm.pandas() #For progress bar

from bs4 import BeautifulSoup
#from prettytable import PrettyTable  # To print in a table
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\tqdm\std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
#Cleaning questions
user1['Q'] = user1['Questions'].progress_apply(clean_text)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 507.99it/s]

# %%
user1['Q']
# Out:
# 0       " i am getting error whiling releasing a part."
# 1         " it says somthing about conditions not met."
# 2                                    " it is x00000255"
# 3                               " ok. how do i do that"
# 4                                                " ok."
# 5        " which category should i use for steel pipe."
# 6                                " still getting error"
# 7     " something about you do not have access to re...
# 8                                          " same part"
# 9                                                " yes"
# 10           " why can`t i release it with my assembly"
# 11                              " ok, who is the owner"
# 12    " ok i send him mail, but this is really frust...
# 13          " yes, can you ask him to relase the part."
# 14                                           " thanks."
# 15    " yes. how to delete this circular icon i got ...
# 16          " why do i get it even though i got error."
# 17    " you can select item revision and do where re...
# 18                " ok i will do it. give me a moment."
# 19                                             " done."
# 20                " anything else can i help you with."
# 21                " ok. i cant open it. access denied."
# 22                          " ok. what is meant by slu"
# 23                                    " ok thanks, bye"
# Name: Q, dtype: object

# %%
#Cleaning questions
Human1['Ans'] = Human1['Answers'].progress_apply(clean_text)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 4000.45it/s]

# %%
Human1
# Out:
#     Unnamed: 0                                            Answers  \
# 0            0                        "  How can I help you?"\r\n
# 1            1                 " what error are you getting?"\r\n
# 2            2  "  Can you give me part number you are trying ...
# 3            3  "  I have done a quick check and found that yo...
# 4            4  "  Refer this instruction document to classify...
# 5            5                          "  use raw materials"\r\n
# 6            6                 "  what does it say this time"\r\n
# 7            7                                  " which part"\r\n
# 8            8                                  " X00000211?"\r\n
# 9            9                           " ok. let me check."\r\n
# 10          10  "  This part is not released and belong to ele...
# 11          11  "  Sorry, it is not allowed to release parts b...
# 12          12                     " Kjetil Kleppe is owner."\r\n
# 13          13  "  I can understand. can i help with something...
# 14          14                          "  ok. will do that."\r\n
# 15          15          " Anything else cal i help you with."\r\n
# 16          16           "  that is a work in progress icon."\r\n
# 17          17                    "  yes it should not come."\r\n
# 18          18  "  i dont know what you are talking about. can...
# 19          19                                     "  thanks"\r\n
# 20          20  " yes, i am new to company, where can i find t...
# 21          21  "  you can get all TC help on intranet site ht...
# 22          22  "  please send ticket to IT helpdesk at helpde...
# 23          23  "  SLU is a 120% BOM for a particular engine t...
#
#                                                   Ans
# 0                              " how can i help you?"
# 1                      " what error are you getting?"
# 2   " can you give me part number you are trying t...
# 3   " i have done a quick check and found that you...
# 4   " refer this instruction document to classify....
# 5                                " use raw materials"
# 6                       " what does it say this time"
# 7                                       " which part"
# 8                                       " x00000211?"
# 9                                " ok. let me check."
# 10  " this part is not released and belong to elec...
# 11  " sorry, it is not allowed to release parts be...
# 12                         " kjetil kleppe is owner."
# 13  " i can understand. can i help with something ...
# 14                               " ok. will do that."
# 15              " anything else cal i help you with."
# 16                " that is a work in progress icon."
# 17                         " yes it should not come."
# 18  " i dont know what you are talking about. can ...
# 19                                          " thanks"
# 20  " yes, i am new to company, where can i find t...
# 21  " you can get all tc help on intranet site htt...
# 22    " please send ticket to it helpdesk at helpdesk
# 23  " slu is a 120% bom for a particular engine ty...

# %%
df = pd.DataFrame(user1['Q'])
df1 = pd.DataFrame(Human1['Ans'])

file = pd.concat([df,df1], axis=1)
file
# Out:
#                                                     Q  \
# 0     " i am getting error whiling releasing a part."
# 1       " it says somthing about conditions not met."
# 2                                  " it is x00000255"
# 3                             " ok. how do i do that"
# 4                                              " ok."
# 5      " which category should i use for steel pipe."
# 6                              " still getting error"
# 7   " something about you do not have access to re...
# 8                                        " same part"
# 9                                              " yes"
# 10         " why can`t i release it with my assembly"
# 11                            " ok, who is the owner"
# 12  " ok i send him mail, but this is really frust...
# 13        " yes, can you ask him to relase the part."
# 14                                         " thanks."
# 15  " yes. how to delete this circular icon i got ...
# 16        " why do i get it even though i got error."
# 17  " you can select item revision and do where re...
# 18              " ok i will do it. give me a moment."
# 19                                           " done."
# 20              " anything else can i help you with."
# 21              " ok. i cant open it. access denied."
# 22                        " ok. what is meant by slu"
# 23                                  " ok thanks, bye"
#
#                                                   Ans
# 0                              " how can i help you?"
# 1                      " what error are you getting?"
# 2   " can you give me part number you are trying t...
# 3   " i have done a quick check and found that you...
# 4   " refer this instruction document to classify....
# 5                                " use raw materials"
# 6                       " what does it say this time"
# 7                                       " which part"
# 8                                       " x00000211?"
# 9                                " ok. let me check."
# 10  " this part is not released and belong to elec...
# 11  " sorry, it is not allowed to release parts be...
# 12                         " kjetil kleppe is owner."
# 13  " i can understand. can i help with something ...
# 14                               " ok. will do that."
# 15              " anything else cal i help you with."
# 16                " that is a work in progress icon."
# 17                         " yes it should not come."
# 18  " i dont know what you are talking about. can ...
# 19                                          " thanks"
# 20  " yes, i am new to company, where can i find t...
# 21  " you can get all tc help on intranet site htt...
# 22    " please send ticket to it helpdesk at helpdesk
# 23  " slu is a 120% bom for a particular engine ty...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from collections import Counter

qsn_cnt = Counter()
for text in user1['Q'].values:
    for word in text.split():
        qsn_cnt[word] += 1


ans_cnt = Counter()
for text in Human1['Ans'].values:
    for word in text.split():
        ans_cnt[word] += 1

# %%
qsn_cnt.most_common(10)
# Out:
# [('"', 24),
#  ('i', 11),
#  ('do', 6),
#  ('to', 5),
#  ('it', 4),
#  ('is', 4),
#  ('you', 4),
#  ('a', 3),
#  ('part."', 3),
#  ('ok.', 3)]

# %%
most_cmn = {k for k,v in qsn_cnt.most_common(20)}

# %%
print(set(stop_words).intersection(most_cmn))
print(len(set(stop_words).intersection(most_cmn)))
# Out:
# {'the', 'i', 'to', 'you', 'this', 'about', 'a', 'it', 'do', 'how', 'can', 'is', 'not'}
# 13

# %%
file.describe()
# Out:
#                                                         Q  \
# count                                                  24
# unique                                                 24
# top     " something about you do not have access to re...
# freq                                                    1
#
#                                                       Ans
# count                                                  24
# unique                                                 24
# top     " slu is a 120% bom for a particular engine ty...
# freq                                                    1
